# %%
from ultralytics import YOLO
import cv2 as cv

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="train.yaml",
    epochs=5
)
# Out:
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G       2.56      3.288      1.883         14        640: 100%|██████████| 289/289 [56:24<00:00, 11.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 37/37 [04:11<00:00,  6.79s/it]
#                    all       1153       4153      0.258       0.25      0.162     0.0552
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5         0G      2.297      2.581      1.636         17        640: 100%|██████████| 289/289 [50:45<00:00, 10.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 37/37 [03:27<00:00,  5.62s/it]
# ...
