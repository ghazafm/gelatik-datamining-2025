# %% [markdown]
# <a href="https://colab.research.google.com/github/ghazafm/gelatik-datamining-2025/blob/master/Ingesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # For Your Information
# * Buat yang mau belajar CNN dari dasar banget<br>
# https://www.youtube.com/watch?v=RavEf7qgUz0&list=PLYTTx9MHqpB_jr4UmeGUO1daHkVIh8Xy6
# * What is Yolo? What is Object Detection?<br>
# https://www.v7labs.com/blog/yolo-object-detection <br>
# Link di atas itu isinya cuman object detection sama apa itu yolo. Kekurangan mungkin disitu ga dijelasin apa itu CNN, sama apa itu yolov8. Tapi overall cocok buat dibaca soalnya lumayan enteng
# * Yolov8 Doc <br>
# https://docs.ultralytics.com/models/yolov8/
# * Systematic Literature Review dari object detection (buat cari model mana yg paling bagus)<br> General <br>
# https://link.springer.com/article/10.1007/s11042-023-15981-y <br>
# Khusus Api/Kebakaran/dan sejenisnya<br>
# * How To Use Roboflow

# %%
# !wget "https://ieee-dataport.s3.amazonaws.com/open/137919/9746/%239%29%20254p%20Frame%20Pairs.zip?AWSAccessKeyId=AKIAJOHYI4KJCE6Q7MIQ&Expires=1736393196&Signature=u5JwIlIZIpofhFwlP%2BEkAuoCoc8%3D"
# Out:
# --2025-01-09 02:27:01--  https://ieee-dataport.s3.amazonaws.com/open/137919/9746/%239%29%20254p%20Frame%20Pairs.zip?AWSAccessKeyId=AKIAJOHYI4KJCE6Q7MIQ&Expires=1736393196&Signature=u5JwIlIZIpofhFwlP%2BEkAuoCoc8%3D
# Resolving ieee-dataport.s3.amazonaws.com (ieee-dataport.s3.amazonaws.com)... 3.5.28.204, 16.182.96.193, 52.217.17.60, ...
# Connecting to ieee-dataport.s3.amazonaws.com (ieee-dataport.s3.amazonaws.com)|3.5.28.204|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8917245884 (8.3G) [application/octet-stream]
# Saving to: ‘#9) 254p Frame Pairs.zip?AWSAccessKeyId=AKIAJOHYI4KJCE6Q7MIQ&Expires=1736393196&Signature=u5JwIlIZIpofhFwlP+EkAuoCoc8=’
#
# #9) 254p Frame Pair 100%[===================>]   8.30G  29.8MB/s    in 4m 28s
#
# 2025-01-09 02:31:29 (31.7 MB/s) - ‘#9) 254p Frame Pairs.zip?AWSAccessKeyId=AKIAJOHYI4KJCE6Q7MIQ&Expires=1736393196&Signature=u5JwIlIZIpofhFwlP+EkAuoCoc8=’ saved [8917245884/8917245884]

# %%
# !unzip "/content/#9) 254p Frame Pairs.zip?AWSAccessKeyId=AKIAJOHYI4KJCE6Q7MIQ&Expires=1736393196&Signature=u5JwIlIZIpofhFwlP+EkAuoCoc8="
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 254p Thermal Images/254p Thermal Frame (5499).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (55).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (550).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5500).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5501).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5502).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5503).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5504).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5505).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5506).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5507).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5508).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (5509).jpg
#   inflating: 254p Thermal Images/254p Thermal Frame (551).jpg
# ...

# %%
# !pip install roboflow

# %%
# import os
# from roboflow import Roboflow

# # Initialize the Roboflow object with your API key
# rf = Roboflow(api_key="IK9Jb9qlny3R7ROyGSnr")

# # Define the workspace and project details
# workspace_id = "fadhilah-hilmi-hym4y"
# project_id = "bcc-telat-daftar"
# project = rf.workspace(workspace_id).project(project_id)

# # Define the folder containing your images
# folder_path = "/content/254p Thermal Images"

# # Iterate through each file in the folder and upload it
# for filename in os.listdir(folder_path):
#     file_path = os.path.join(folder_path, filename)
#     if os.path.isfile(file_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg')):
#         print(f"Uploading {filename}...")
#         project.upload(image_path=file_path)
#         print(f"Uploaded {filename}")

# %%
import os
from roboflow import Roboflow

# Initialize the Roboflow object with your API key
rf = Roboflow(api_key="IK9Jb9qlny3R7ROyGSnr")

# Define the workspace and project details
workspace_id = "fadhilah-hilmi-hym4y"
project_id = "bcc-telat-daftar"
project = rf.workspace(workspace_id).project(project_id)

# Define the folder containing your images
folder_path = "/content/254p RGB Images"

# Iterate through each file in the folder and upload it
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path) and filename.lower().endswith(
        (".png", ".jpg", ".jpeg")
    ):
        print(f"Uploading {filename}...")
        project.upload(image_path=file_path)
        print(f"Uploaded {filename}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Uploaded 254p RGB Frame (30002).jpg
# Uploading 254p RGB Frame (49683).jpg...
# Uploaded 254p RGB Frame (49683).jpg
# Uploading 254p RGB Frame (6894).jpg...
# Uploaded 254p RGB Frame (6894).jpg
# Uploading 254p RGB Frame (18792).jpg...
# Uploaded 254p RGB Frame (18792).jpg
# Uploading 254p RGB Frame (49910).jpg...
# Uploaded 254p RGB Frame (49910).jpg
# Uploading 254p RGB Frame (30249).jpg...
# Uploaded 254p RGB Frame (30249).jpg
# Uploading 254p RGB Frame (33443).jpg...
# Uploaded 254p RGB Frame (33443).jpg
# Uploading 254p RGB Frame (1656).jpg...
# Uploaded 254p RGB Frame (1656).jpg
# Uploading 254p RGB Frame (35265).jpg...
# Uploaded 254p RGB Frame (35265).jpg
# Uploading 254p RGB Frame (6241).jpg...
# Uploaded 254p RGB Frame (6241).jpg
# Uploading 254p RGB Frame (15944).jpg...
# Uploaded 254p RGB Frame (15944).jpg
# Uploading 254p RGB Frame (8742).jpg...
# Uploaded 254p RGB Frame (8742).jpg
# ...

# %%
# lib buat manggil pretrained yolo
# !pip install ultralytics

# %%
import ultralytics
